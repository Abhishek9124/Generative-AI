# %%
# !pip install -q google-generativeai

# %%
#with_structed_output_typeddict
import os
from google import genai
from google.genai import types
from dotenv import load_dotenv
load_dotenv()
client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))
client

# %%
# print(client.api_key)

# %% [markdown]
#  Text Generation

# %%
# from google import genai

# %%
response=client.models.generate_content(model='gemini-2.5-pro',contents="""PRIME MINISTER OF INDIA in 400 words? """)
print(response.text)
# Out:
# The Prime Minister of India is the head of government and the most powerful political figure in the Republic of India. Operating within a parliamentary system, the Prime Minister functions as the chief executive, exercising the real executive authority of the nation, although the President of India is the formal head of state.
#
# The appointment of the Prime Minister is a cornerstone of India's democratic process. Following a general election to the Lok Sabha (the lower house of Parliament), the President invites the leader of the political party or coalition that commands a majority of seats to form the government. The Prime Minister, who must be a member of either the Lok Sabha or the Rajya Sabha (the upper house), is then sworn into office by the President.
#
# ...

# %%
response   #metadata
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""The Prime Minister of India is the head of government and the chief executive of the Republic of India. Unlike the President, who is the ceremonial Head of State, the Prime Minister wields the real executive power, making them the most powerful political office in the country. This position is the linchpin of India's parliamentary democratic system, deeply rooted in the Westminster model.
#
# ...

# %%
# gemini 2.5 pro has the thinking capability

# %%
# Additional Configuration
# config parameter
# generatecontentconfig class object

# %%
from google.genai import types
# how they should behavive during output , model personality , structured output , used different in education , military , etc
response=client.models.generate_content(
    model='gemini-2.5-flash-lite',
    contents='Who is Donald Trump? ',
    config=types.GenerateContentConfig(system_instruction='You are an very rudel person , you always speaks rudely to people , but you never abuses. You gave output in very short lines or paragraphs')
)

# %%
response.text
# Out:
# "He's the 45th President of the United States.\nBefore that, he was a real estate developer and a reality TV star.\nHe's a Republican."

# %%
# -------------------------------
# System Instructions
# -------------------------------
system_instructions = """
You are a corporate legal assistant.
Your job is to extract the following from any B2B contract text:
1. Contract start and end dates,
2. Payment terms,
3. Termination conditions,
4. Any penalty or liability clauses.
Output only what you find, in tabular form.
"""

# -------------------------------
# Contract Content
# -------------------------------
contents = """
This agreement is entered into on May 1st, 2024 and shall remain in effect until April 30, 2025.
Payment is due within 45 days of invoice date. Late payments may incur a penalty of 3% monthly.
Either party may terminate this agreement with 60 days' notice.
"""

# -------------------------------
# Model Call
# -------------------------------
response = client.models.generate_content(
    model="gemini-2.5-flash",  # or "gpt-5", "gemini-1.5-flash", etc.
    config=types.GenerateContentConfig(
        system_instruction=system_instructions
    ),
    contents=contents
)

# -------------------------------
# Output
# -------------------------------
print(response.text)
# Out:
# | Category                     | Details                                       |
# | :--------------------------- | :-------------------------------------------- |
# | **Contract Start Date**      | May 1st, 2024                                 |
# | **Contract End Date**        | April 30, 2025                                |
# | **Payment Terms**            | Due within 45 days of invoice date            |
# | **Termination Conditions**   | Either party may terminate with 60 days' notice |
# | **Penalty/Liability Clauses** | Late payments may incur a penalty of 3% monthly |

# %%
#max output tokens

# %%
from google.genai import types
# how they should behavive during output , model personality , structured output , used different in education , military , etc
response=client.models.generate_content(
    model='gemini-2.5-flash-lite',
    contents='Who is Donald Trump? ',
    config=types.GenerateContentConfig(max_output_tokens=100)
)
print(response.text)
# Out:
# Donald Trump is an American businessman, media personality, and politician who served as the 45th President of the United States from 2017 to 2021.
#
# Here's a breakdown of his background and career:
#
# **Early Life and Business Career:**
#
# *   **Born:** June 14, 1946, in Queens, New York City.
# *   **Family:** He is the son of Fred Trump, a real estate developer

# %%
from google.genai import types
# how they should behavive during output , model personality , structured output , used different in education , military , etc
response=client.models.generate_content(
    model='gemini-2.5-flash-lite',
    contents='Who is Donald Trump? ',
    config=types.GenerateContentConfig(max_output_tokens=100,candidateCount=2)
)
print(response)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=10>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""Donald Trump is an American businessman, television personality, and politician. He served as the 45th President of the United States from 2017 to 2021.
#
# Here's a breakdown of his career and public life:
#
# **Early Life and Business Career:**
#
# *   Born in Queens, New York, in 1946.
# *   He inherited and significantly expanded his father Fred Trump's real estate business, renaming it The Trump Organization"""
#       ),
#       Part(
#         text="""Donald Trump is an American businessman, media personality, and politician. He served as the 45th President of the United States from 2017 to 2021.
#
# Here's a breakdown of his career and prominent roles:
#
# ...

# %% [markdown]
# MULTIMODEL CAPABILITIES

# %%
from PIL import Image
from io import BytesIO
import base64
import google.generativeai as genai  # Make sure you imported this
import os
from google import genai
from google.genai import types
from dotenv import load_dotenv
load_dotenv()
client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))
client

# Open the image properly (fixed file path syntax)
image = Image.open("/content/deep_meaning.jpeg")

# Generate response using the correct syntax
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[image, "explain me this with real life simple example."]
)

# Print the model's output
print(response.text)
# Out:
# This beautiful image is a powerful metaphor for **parental love and sacrifice, especially in helping children achieve their dreams and potential.**
#
# Let's break it down with a simple real-life example:
#
# **Imagine the Woman as a Parent (Mother/Father) and the Boy as their Child.**
#
# *   **The Woman's Tattered Wings:** These represent the parent's own life journey, their struggles, their hard work, and the "flights" they've taken. Maybe they had to work incredibly hard, face obstacles, or even put their own dreams aside to build a life. Their wings are worn because they've used them extensively, perhaps carrying burdens or flying through difficult times.
# *   **The Feathers:** These represent opportunities, education, financial support, lessons learned, encouragement, guidance, and all the resources a parent provides. They are the "ingredients" for success and independence.
# ...

# %% [markdown]
# IMAGE GENERATION

# %%
# modality--> means output type we want

# %%
# from google import genai
# from google.genai import types
# from PIL import Image
# from io import BytesIO
# import os
# from dotenv import load_dotenv
# load_dotenv()
# client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))
# client

# response = client.models.generate_images(
#     model='gemini-2.5-flash-lite',
#     prompt='Robot holding a red skateboard',
#     config=types.GenerateImagesConfig(
#         number_of_images= 4,
#     )
# )
# for generated_image in response.generated_images:
#   generated_image.image.show()

# %%
# for m in client.models.list():
#   print(m)

# %% [markdown]
# IMAGE EDITING

# %%
# inserting soft in the blank room

# %% [markdown]
# SPEECH GENERATION

# %%
# text -> speech
# modality --> audio
# SpeechConfig --> tone of the voice
# voiceConfig  --> prebuiltvoiceCOnfig --> voice_name

# %%
# voice_options  Refer Documentation

# %%
import os
from google import genai
from google.genai import types
from dotenv import load_dotenv
load_dotenv()
client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))
client

# %%
content = """
In a cheerful female voice: Hey, how are you today?
In a deep male voice: I'm doing great, thanks for asking!
In a soft female voice: The weather is really nice, isn't it?
In a young male voice: Absolutely, perfect for a walk in the park!
In an excited female voice: Did you see the festival decorations?
In a calm male voice: Yes, they look beautiful and vibrant.
In a playful female voice: Let's go try some of the street food.
In a serious male voice: Good idea, we should also stay safe.
In a happy female voice: I love this city during festive times!
In a warm male voice: Me too, it feels like everyone is smiling.
"""
response = client.models.generate_content(
    model="gemini-2.5-flash-preview-tts",
    contents=content,
    config=types.GenerateContentConfig(
        response_modalities=["AUDIO"],
        speech_config = types.SpeechConfig(
            voice_config=types.VoiceConfig(
                prebuilt_voice_config=types.PrebuiltVoiceConfig(
                    voice_name= 'Kore'
                )
            )
        ),
    )
)

# %%
data=response.candidates[0].content.parts[0].inline_data.data

# %%
# .wav
# channel --> 1(mono),2{stereo}
# samplewidth -->  clearity 8,16 bits
# framerate -->
import wave

# %%
def wave_file(filename,input):
    with wave.open(filename,'wb') as wf:
        wf.setnchannels(1)
        wf.setsampwidth(2)
        wf.setframerate(24000)
        wf.writeframes(input)

# %%
file_name='output1.wav'
wave_file(file_name,data)
from IPython.display import Audio

# Play the generated audio file
Audio("output1.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install -q google.genai

# %%
# refer Notes of this Module
